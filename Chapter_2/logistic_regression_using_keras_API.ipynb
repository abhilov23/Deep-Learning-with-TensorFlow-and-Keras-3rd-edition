# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow.keras as K
from tensorflow.keras.layers import Dense, Flatten

# %%
((train_data, train_labels),(test_data, test_labels)) = tf.keras.datasets.mnist.load_data()

# %%
train_data = train_data/np.float32(255)
train_labels = train_labels.astype(np.int32)  
test_data = test_data/np.float32(255)
test_labels = test_labels.astype(np.int32)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], shape=(60000,), dtype=int32)

# %%
model = K.Sequential([
                      # Dense(64,  activation='relu'),
                      # Dense(32,  activation='relu'),
                      Flatten(input_shape=(28, 28)),
                      Dense(10, activation='sigmoid')
])
model.summary()
# Out:
# c:\Users\Abhilov\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         7,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,850 (30.66 KB)
#  Trainable params: 7,850 (30.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x=train_data,y=train_labels, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# c:\Users\Abhilov\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\nn.py:717: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8705 - loss: 0.5061 - val_accuracy: 0.9142 - val_loss: 0.3181
# Epoch 2/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9126 - loss: 0.3176 - val_accuracy: 0.9216 - val_loss: 0.2875
# Epoch 3/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9179 - loss: 0.2927 - val_accuracy: 0.9231 - val_loss: 0.2775
# Epoch 4/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9216 - loss: 0.2811 - val_accuracy: 0.9245 - val_loss: 0.2716
# Epoch 5/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9232 - loss: 0.2738 - val_accuracy: 0.9269 - val_loss: 0.2665
# Epoch 6/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9262 - loss: 0.2678 - val_accuracy: 0.9277 - val_loss: 0.2644
# Epoch 7/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9263 - loss: 0.2637 - val_accuracy: 0.9275 - val_loss: 0.2643
# Epoch 8/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9275 - loss: 0.2607 - val_accuracy: 0.9302 - val_loss: 0.2611
# Epoch 9/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9286 - loss: 0.2574 - val_accuracy: 0.9277 - val_loss: 0.2628
# Epoch 10/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9287 - loss: 0.2555 - val_accuracy: 0.9291 - val_loss: 0.2611
# Epoch 11/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9297 - loss: 0.2532 - val_accuracy: 0.9295 - val_loss: 0.2613
# Epoch 12/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9293 - loss: 0.2510 - val_accuracy: 0.9288 - val_loss: 0.2624
# Epoch 13/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9308 - loss: 0.2494 - val_accuracy: 0.9302 - val_loss: 0.2610
# Epoch 14/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9308 - loss: 0.2480 - val_accuracy: 0.9302 - val_loss: 0.2621
# Epoch 15/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9307 - loss: 0.2467 - val_accuracy: 0.9299 - val_loss: 0.2616
# Epoch 16/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9306 - loss: 0.2459 - val_accuracy: 0.9299 - val_loss: 0.2628
# Epoch 17/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9322 - loss: 0.2443 - val_accuracy: 0.9310 - val_loss: 0.2614
# Epoch 18/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9330 - loss: 0.2431 - val_accuracy: 0.9307 - val_loss: 0.2619
# Epoch 19/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9325 - loss: 0.2423 - val_accuracy: 0.9290 - val_loss: 0.2638
# Epoch 20/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9329 - loss: 0.2409 - val_accuracy: 0.9313 - val_loss: 0.2610
# Epoch 21/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9339 - loss: 0.2405 - val_accuracy: 0.9304 - val_loss: 0.2639
# Epoch 22/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9336 - loss: 0.2395 - val_accuracy: 0.9307 - val_loss: 0.2643
# Epoch 23/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9335 - loss: 0.2388 - val_accuracy: 0.9280 - val_loss: 0.2673
# Epoch 24/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9337 - loss: 0.2384 - val_accuracy: 0.9317 - val_loss: 0.2626
# Epoch 25/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9337 - loss: 0.2376 - val_accuracy: 0.9302 - val_loss: 0.2644
# Epoch 26/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9345 - loss: 0.2371 - val_accuracy: 0.9298 - val_loss: 0.2671
# Epoch 27/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9350 - loss: 0.2363 - val_accuracy: 0.9299 - val_loss: 0.2664
# Epoch 28/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9340 - loss: 0.2356 - val_accuracy: 0.9293 - val_loss: 0.2661
# Epoch 29/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9347 - loss: 0.2350 - val_accuracy: 0.9296 - val_loss: 0.2656
# Epoch 30/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9346 - loss: 0.2347 - val_accuracy: 0.9269 - val_loss: 0.2710
# Epoch 31/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9344 - loss: 0.2340 - val_accuracy: 0.9288 - val_loss: 0.2686
# Epoch 32/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9356 - loss: 0.2337 - val_accuracy: 0.9280 - val_loss: 0.2690
# Epoch 33/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9350 - loss: 0.2332 - val_accuracy: 0.9301 - val_loss: 0.2668
# Epoch 34/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9364 - loss: 0.2320 - val_accuracy: 0.9305 - val_loss: 0.2664
# Epoch 35/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9348 - loss: 0.2323 - val_accuracy: 0.9308 - val_loss: 0.2692
# Epoch 36/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9351 - loss: 0.2321 - val_accuracy: 0.9298 - val_loss: 0.2663
# Epoch 37/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9356 - loss: 0.2314 - val_accuracy: 0.9308 - val_loss: 0.2690
# Epoch 38/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9358 - loss: 0.2306 - val_accuracy: 0.9269 - val_loss: 0.2744
# Epoch 39/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9351 - loss: 0.2311 - val_accuracy: 0.9297 - val_loss: 0.2689
# Epoch 40/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9354 - loss: 0.2304 - val_accuracy: 0.9281 - val_loss: 0.2715
# Epoch 41/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9359 - loss: 0.2303 - val_accuracy: 0.9302 - val_loss: 0.2690
# Epoch 42/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9360 - loss: 0.2290 - val_accuracy: 0.9279 - val_loss: 0.2724
# Epoch 43/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9353 - loss: 0.2299 - val_accuracy: 0.9308 - val_loss: 0.2689
# Epoch 44/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9366 - loss: 0.2291 - val_accuracy: 0.9294 - val_loss: 0.2703
# Epoch 45/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9362 - loss: 0.2286 - val_accuracy: 0.9285 - val_loss: 0.2724
# Epoch 46/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9360 - loss: 0.2282 - val_accuracy: 0.9292 - val_loss: 0.2738
# Epoch 47/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9354 - loss: 0.2285 - val_accuracy: 0.9295 - val_loss: 0.2720
# Epoch 48/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9372 - loss: 0.2277 - val_accuracy: 0.9297 - val_loss: 0.2726
# Epoch 49/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9366 - loss: 0.2275 - val_accuracy: 0.9301 - val_loss: 0.2741
# Epoch 50/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9372 - loss: 0.2269 - val_accuracy: 0.9290 - val_loss: 0.2735

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# %%
predictions = model.predict(test_data)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("Pred {} Conf: {:2.0f}% True ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 56
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_data)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
better_model = K.Sequential([
                      Flatten(input_shape=(28, 28)),
                      Dense(128,  activation='relu'),
                      #Dense(64,  activation='relu'),
                      Dense(10, activation='softmax')
])
better_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
better_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = better_model.fit(x=train_data,y=train_labels, epochs=10, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9186 - loss: 0.2871 - val_accuracy: 0.9543 - val_loss: 0.1622
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9625 - loss: 0.1258 - val_accuracy: 0.9681 - val_loss: 0.1100
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9744 - loss: 0.0859 - val_accuracy: 0.9691 - val_loss: 0.1031
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9812 - loss: 0.0640 - val_accuracy: 0.9717 - val_loss: 0.0974
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9849 - loss: 0.0498 - val_accuracy: 0.9747 - val_loss: 0.0848
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9878 - loss: 0.0397 - val_accuracy: 0.9719 - val_loss: 0.0954
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9909 - loss: 0.0305 - val_accuracy: 0.9732 - val_loss: 0.0956
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9925 - loss: 0.0252 - val_accuracy: 0.9728 - val_loss: 0.0964
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9941 - loss: 0.0200 - val_accuracy: 0.9762 - val_loss: 0.0848
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9948 - loss: 0.0165 - val_accuracy: 0.9753 - val_loss: 0.0966

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# %%
predictions = better_model.predict(test_data)
i = 0
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_data)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
