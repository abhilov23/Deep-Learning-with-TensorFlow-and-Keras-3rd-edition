# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow.keras as K
from tensorflow.keras.layers import Dense, Normalization
import seaborn as sns

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data' 
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
                'acceleration', 'model_year', 'origin']

data = pd.read_csv(url, names=column_names,
                    na_values='?', comment='\t',
                    sep=' ', skipinitialspace=True)

# %%
# drop the 'origin' column using a keyword for clarity
data = data.drop(columns='origin')
print(data.isna().sum())
data = data.dropna()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# dtype: int64

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
# dtypes: float64(5), int64(2)
# memory usage: 24.5 KB

# %%
train_dataset = data.sample(frac=0.8, random_state=0)
test_dataset = data.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['mpg', 'cylinders', 'displacement','horsepower', 'weight', 'acceleration', 'model_year']], diag_kind='kde')

# %%
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                      mean         std
# mpg             23.310510    7.728652
# cylinders        5.477707    1.699788
# displacement   195.318471  104.331589
# horsepower     104.869427   38.096214
# weight        2990.251592  843.898596
# acceleration    15.559236    2.789230
# model_year      75.898089    3.675642

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy() 

train_labels = train_features.pop('mpg')
test_labels = test_features.pop('mpg')

# %%
#Normalize
data_normalizer = Normalization(axis=1)
data_normalizer.adapt(np.array(train_features))

# %%
model = K.Sequential([
                      data_normalizer,
                      Dense(64,  activation='relu'),
                      Dense(32,  activation='relu'),
                      Dense(1,  activation=None)
])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (314, 6)               │            13 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (56.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 13 (56.00 B)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(x=train_features,y=train_labels, epochs=100, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 601.5009 - val_loss: 617.1074
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 582.3132 - val_loss: 597.2784
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 563.9351 - val_loss: 576.8193
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 544.1899 - val_loss: 554.7896
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 522.1713 - val_loss: 529.9591
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 497.4359 - val_loss: 501.2794
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 468.5827 - val_loss: 468.3524
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 436.0481 - val_loss: 430.9967
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 398.6725 - val_loss: 389.9703
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 359.5376 - val_loss: 344.5688
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 314.7001 - val_loss: 296.9355
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 267.7412 - val_loss: 247.2899
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 220.8935 - val_loss: 196.7216
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 174.4597 - val_loss: 148.6141
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 131.4501 - val_loss: 106.5614
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 94.2227 - val_loss: 74.5947
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 66.9614 - val_loss: 53.8903
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 50.7984 - val_loss: 43.0365
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 42.0770 - val_loss: 39.3650
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 37.9560 - val_loss: 38.1379
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36.2045 - val_loss: 36.8616
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 34.3646 - val_loss: 35.0938
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.6525 - val_loss: 32.7835
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 30.6378 - val_loss: 30.9512
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.1626 - val_loss: 29.3826
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.6127 - val_loss: 27.9538
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.2292 - val_loss: 26.6796
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.9343 - val_loss: 25.4441
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.8259 - val_loss: 24.1443
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.6845 - val_loss: 23.2329
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.8124 - val_loss: 22.3735
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.8097 - val_loss: 21.4621
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.9754 - val_loss: 20.5876
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.1778 - val_loss: 19.8798
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.4288 - val_loss: 19.1559
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.8107 - val_loss: 18.4218
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.1258 - val_loss: 17.8706
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.5101 - val_loss: 17.2489
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.9509 - val_loss: 16.7965
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.4374 - val_loss: 16.4421
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.9702 - val_loss: 15.8354
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.5092 - val_loss: 15.4431
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.0815 - val_loss: 15.1879
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13.6834 - val_loss: 14.7860
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.2835 - val_loss: 14.4390
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.9941 - val_loss: 14.1669
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.6410 - val_loss: 13.9510
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.3677 - val_loss: 13.7840
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.0645 - val_loss: 13.4854
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.8385 - val_loss: 13.2390
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.5585 - val_loss: 13.0977
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.3728 - val_loss: 12.8915
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 11.1903 - val_loss: 12.8261
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.9830 - val_loss: 12.7255
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.8212 - val_loss: 12.5166
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.6488 - val_loss: 12.4088
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.5160 - val_loss: 12.3202
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.3641 - val_loss: 12.1621
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.2021 - val_loss: 12.1134
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.0971 - val_loss: 11.9929
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9625 - val_loss: 11.9543
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8383 - val_loss: 11.8112
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.7151 - val_loss: 11.7019
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6190 - val_loss: 11.6636
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5380 - val_loss: 11.5964
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.4506 - val_loss: 11.6120
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.3246 - val_loss: 11.4806
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.2299 - val_loss: 11.3860
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.1528 - val_loss: 11.3292
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.0670 - val_loss: 11.2853
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.0003 - val_loss: 11.2319
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9359 - val_loss: 11.2140
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.8313 - val_loss: 11.0993
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7696 - val_loss: 10.9726
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7333 - val_loss: 10.9132
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.6175 - val_loss: 10.9443
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.5663 - val_loss: 10.8960
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5033 - val_loss: 10.7700
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4505 - val_loss: 10.6270
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4006 - val_loss: 10.6114
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.3197 - val_loss: 10.5025
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3089 - val_loss: 10.5169
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2071 - val_loss: 10.5190
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2007 - val_loss: 10.4174
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.0922 - val_loss: 10.3854
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1604 - val_loss: 10.4472
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.0163 - val_loss: 10.3476
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.9750 - val_loss: 10.3330
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.9159 - val_loss: 10.2761
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.8831 - val_loss: 10.2470
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8318 - val_loss: 10.1812
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7916 - val_loss: 10.1475
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7415 - val_loss: 10.0954
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7479 - val_loss: 10.0201
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6993 - val_loss: 10.1508
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6371 - val_loss: 10.0598
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5884 - val_loss: 9.9798
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5489 - val_loss: 9.9821
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5262 - val_loss: 9.9572
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4852 - val_loss: 9.9063

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()
plt.grid(True)

# %%
y_pred = model.predict(test_features).flatten()
a = plt.axes(aspect='equal')
plt.scatter(test_labels, y_pred)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
error = y_pred - test_labels
plt.hist(error, bins=30)
plt.xlabel('Prediction Error [MPG]')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
